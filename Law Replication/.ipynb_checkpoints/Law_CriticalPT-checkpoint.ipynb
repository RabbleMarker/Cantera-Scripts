# %% [markdown]
# # Law Replication: Critical Temperatures and Pressures of H2-Air & Me-Air Mixtures
#
# This Code tries to calculate and compare critical Pressures and Temperatures of Hydrogen-Air and Methane-Air mixtures. \
# We obtain the these properties from:
# 1. Using Kays Rule on the pure Fluids (pseudocritical, quite inaccurate)
# 2. CoolProps all_critical_points function (more accurate, but has its own pitfalls)
# 3. Reference values from Liang, Chung K. Law et al's paper (https://doi.org/10.1016/j.proci.2018.06.070)
#
# Lastly, we seee how our obtained values change with tuning some of the binary interaction parameters in H2-Air
#
# Sources: \
# Burke Mechanism: https://burke.me.columbia.edu/sites/burke.me.columbia.edu/files/content/chem_cti.txt \
# Cantera Critical State Properties: https://cantera.org/stable/examples/python/thermo/critical_properties.html \
# Coolprop Cubic EOS: http://www.coolprop.org/coolprop/Cubics.html \
# Coolprop Mixture Handling: http://www.coolprop.org/dev/fluid_properties/Mixtures.html \
# Coolprop Low Level Interface: http://www.coolprop.org/coolprop/LowLevelAPI.html

# %%
#Imports
import cantera as ct
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import CoolProp.CoolProp as CP
from CoolProp.CoolProp import PropsSI
# !pip install pandas if you dont have it
import pandas as pd

# %% [markdown]
# First we are grabbing the Critical Properties of Pure fluids from Canteras built-in EOSs and Coolprops EOS and Comparing them to the values found in the NIST Database, to get a feel for how accurate they are. \
# Canteras code is analogous to Canteras Critical State Properties example. \

# %%
fluids = {'N2': ct.Nitrogen(),
          'CH4': ct.Methane(),
          'H2': ct.Hydrogen(),
          'O2': ct.Oxygen(),
          }
print('Critical State Properties')
print(f"{'Fluid':^16s}   {'Tc [K]':^7s}   {'Pc [Atm]':^10s} {'Zc':^7s}")
print(f"{'-'*16}   {'-'*7}   {'-'*10} {'-'*7}")

for name in fluids:
    f = fluids[name]
    tc = f.critical_temperature
    pc = f.critical_pressure
    rc = f.critical_density
    mw = f.mean_molecular_weight # g/kmol
    zc = pc * mw / (rc * ct.gas_constant * tc)
    print(f'{name:16s}   {tc:7.2f}   {pc/101325:10.4g} {zc:7.4f}')


print()
print('Critical State Properties in Coolprop')
print(f"{'Fluid':^16s}   {'Tc [K]':^7s}   {'Pc [Atm]':^10s} {'Zc':^7s}")
print(f"{'-'*16}   {'-'*7}   {'-'*10} {'-'*7}")

# PropsSI doesn't like using indexes in its function
# That is why we need to use CoolProps low level interface, which does accept these inputs
CP_fluids = ['N2', 'CH4', 'H2', 'O2']

for X in CP_fluids:
    name1 = X
    tc1 = PropsSI("Tcrit", "P", 101325, "T", 300, X)
    pc1 = PropsSI("pcrit", "P", 101325, "T", 300, X)
    rc1 = PropsSI("rhocrit", "P", 101325, "T", 300, X)
    mw1 = PropsSI("molemass", "P", 101325, "T", 300, X) # kg/mol
    zc1 = pc1 * mw1 * 1000 / (rc1 * ct.gas_constant * tc1) # Increased by a factor of 1000 due to unit change
    print(f'{name1:16s}   {tc1:7.2f}   {pc1/101325:10.4g} {zc1:7.4f}')

NIST_Crit = pd.read_csv('NIST Reference Critical Properties.csv')
#NIST_Crit.head()

print()
print('NIST Reference Critical State Properties')
print(f"{'Fluid':^16s}   {'Tc [K]':^7s}   {'Pc [Atm]':^10s} {'Zc':^7s}")
print(f"{'-'*16}   {'-'*7}   {'-'*10} {'-'*7}")

for i in range(len(NIST_Crit)):
    tc2 = NIST_Crit.iloc[i, 2]
    pc2 = NIST_Crit.iloc[i, 3] # atm
    rc2 = NIST_Crit.iloc[i, 4]
    mw2 = NIST_Crit.iloc[i, 1] # g/mol
    zc2 = pc2 * 101325 * mw2 / (rc2 * ct.gas_constant * tc2) # Increased by atm-Pa factor
    print(f'{NIST_Crit.iloc[i, 0]:16s}   {tc2:7.2f}   {pc2:10.4g} {zc2:7.4f}')
# Out:
# Critical State Properties
#      Fluid         Tc [K]     Pc [Atm]    Zc
# ----------------   -------   ---------- -------
# N2                  126.20        33.56  0.2891
# CH4                 190.56        45.39  0.2904
# H2                   32.94        12.67  0.3013
# O2                  154.58        49.77  0.2879
#
# Critical State Properties in Coolprop
#      Fluid         Tc [K]     Pc [Atm]    Zc
# ----------------   -------   ---------- -------
# N2                  126.19        33.51  0.2894
# CH4                 190.56        45.39  0.2863
# H2                   33.15        12.79  0.3033
# O2                  154.58        49.77  0.2879
#
# NIST Reference Critical State Properties
#      Fluid         Tc [K]     Pc [Atm]    Zc
# ----------------   -------   ---------- -------
# N2                  126.19        33.51  0.2894
# CH4                 190.56        45.39  0.2863
# H2                   33.15        12.79  0.3033
# O2                  154.58        49.77  0.2879

# %% [markdown]
# Compared to NIST, CoolProp has more accurate values than Cantera. \
# Now to calculate critical properties of Mixtures:
#
# We set up a range of equivalence ratios between 0.6 and 2 (same as Fig. 2 of paper)

# %%
phi = np.linspace(0.6,2, 29)
print (phi)
# Out:
# [0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25
#  1.3  1.35 1.4  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95
#  2.  ]

# %% [markdown]
# We will first be utilizing Kays Law. It states, that the critical properties of a gas mixture can be estimated as the mole-fraction weighted average of the corresponding critical properties of the pure components.
# We'll use CoolProps Pure Fluid values, since they seem more accurate.

# %% [markdown]
# In order to not have to do molar fractions manually, we will use Canteras set_equivalence_ratio function. For that, we set up the following gas objects:

# %%
#2 Objects, 1 for H2, one for CH4
gas1 = ct.Solution('gri30.yaml')
gas2 = ct.Solution('gri30.yaml')

fuel = 'H2:1'
fuel2 = 'CH4:1'
oxidizer = 'O2:0.21,N2:0.79'

gas1.set_equivalence_ratio(1, fuel, oxidizer)
gas2.set_equivalence_ratio(1, fuel2, oxidizer)
#After setting the equivalence ratio, the molar fractions get automatically adjusted, and can be obtained with gas1.X[species_index]
#The species index is obtained with gas1.X[gas1.species_index('GAS')]

# %%
#Arrays for final values
T_c_mix_H2 = []
P_c_mix_H2 = []
T_c_mix_CH4 = []
P_c_mix_CH4 = []

# Main Loops
for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    #Defining species, mole fractions
    mole_fractions = {
    'N2': gas1.X[gas1.species_index('N2')],
    'H2': gas1.X[gas1.species_index('H2')],
    'O2': gas1.X[gas1.species_index('O2')]
    }
    T_temp = 0
    P_temp = 0
    for species, y in mole_fractions.items():
        T_ci = CP.PropsSI('Tcrit', species)
        P_ci = CP.PropsSI('Pcrit', species)
        T_temp += y * T_ci
        P_temp += y * P_ci
    T_c_mix_H2.append (T_temp)
    P_c_mix_H2.append (P_temp/101325) #atm

for i in phi:
    gas2.set_equivalence_ratio(i, fuel2, oxidizer)
    mole_fractions = {
    'N2': gas2.X[gas2.species_index('N2')],
    'CH4': gas2.X[gas2.species_index('CH4')],
    'O2': gas2.X[gas2.species_index('O2')]
    }
    T_temp = 0
    P_temp = 0
    for species, y in mole_fractions.items():
        T_ci = CP.PropsSI('Tcrit', species)
        P_ci = CP.PropsSI('Pcrit', species)
        T_temp += y * T_ci
        P_temp += y * P_ci
    T_c_mix_CH4.append (T_temp)
    P_c_mix_CH4.append (P_temp/101325) #atm

# %%
#print (T_c_mix_CH4)
#print (P_c_mix_H2)

# %% [markdown]
# Querying critical properties of Mixtures is not implemented in Cantera, as seen below

# %%
gas1.critical_temperature()
#gas1.critical_pressure()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 gas1.critical_temperature()
#       2 #gas1.critical_pressure()
#
# File build/python/cantera/thermo.pyx:1314, in cantera.thermo.ThermoPhase.critical_temperature.__get__()
#
# NotImplementedError:
# *******************************************************************************
# NotImplementedError thrown by ThermoPhase::critTemperature:
# Not implemented.
# *******************************************************************************

# %% [markdown]
# It is however implemented in CoolProp! \
# See http://www.coolprop.org/coolprop/Cubics.html#mixtures \
# As such, we will be using CoolProps backend to calculate our critical mixture values. \
# The main code will use CoolProps low level interface, by setting up an AbstractState (similar to cantera multifluid Object). \
# This is more practical for us compared to the High Level interface, since we can input our cantera gas object indeces directly into the CoolProps set_mole_fractions Function.

# %%
gas1.set_equivalence_ratio(1, fuel, oxidizer)
gas2.set_equivalence_ratio(1, fuel2, oxidizer)

# %%
print('Critical State Properties of Hydrogen-Air Mixtures in Coolprop using different Backends:')
print(' ')
print('Hydrogen SRK:')
AS = CP.AbstractState("SRK", "Nitrogen&Hydrogen&Oxygen") #Species can be written as such
AS.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')],gas1.X[gas1.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)

print('Hydrogen PR:')
AS = CP.AbstractState("PR", "NITROGEN&HYDROGEN&OXYGEN") #Or such
AS.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')],gas1.X[gas1.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)

print('Hydrogen HEOS:')
AS = CP.AbstractState("HEOS", "N2&H2&O2") #Or like this!
AS.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)
# Out:
# Critical State Properties of Hydrogen-Air Mixtures in Coolprop using different Backends:
#
# Hydrogen SRK:
# 120.17183929788499
# 67.70122013450785
# Hydrogen PR:
# 119.49665108532542
# 65.77011694027284
# Hydrogen HEOS:
# 126.05583339608778
# 102.94691284011917

# %%
print('Critical State Properties of Methane-Air Mixtures in Coolprop using different Backends:')

print(' ')
print('Methane SRK:')
AS = CP.AbstractState("SRK", "Nitrogen&Methane&Oxygen")
AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)
print('Methane PR:')
AS = CP.AbstractState("PR", "Nitrogen&Methane&Oxygen")
AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)

print('Methane HEOS, phi 0.5:')
gas2.set_equivalence_ratio(0.5, fuel2, oxidizer)
AS = CP.AbstractState("HEOS", "Nitrogen&Methane&Oxygen")
AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)
# Out:
# Critical State Properties of Methane-Air Mixtures in Coolprop using different Backends:
#
# Methane SRK:
# 138.98817009854451
# 41.14460372098934
# 18.410575152253134
# -1081.9140763288628
# Methane PR:
# 138.8881782344944
# 41.08612216960375
# Methane HEOS, phi 0.5:
# 122.48254229728366
# 24.473548767515986
# 121.17893256811705
# 155.92912218836793
# 125.43379401798722
# 61.78616715691556

# %%
print('Methane HEOS, phi 0.65:')
gas2.set_equivalence_ratio(0.65, fuel2, oxidizer)
AS = CP.AbstractState("HEOS", "Nitrogen&Methane&Oxygen")
AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)
# Out:
# Methane HEOS, phi 0.65:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       3 AS = CP.AbstractState("HEOS", "Nitrogen&Methane&Oxygen")
#       4 AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
# ----> 5 pts = AS.all_critical_points()
#       6 for pt in pts:
#       7     print (pt.T)
#
# File CoolProp/AbstractState.pyx:168, in CoolProp.CoolProp.AbstractState.all_critical_points()
#
# File CoolProp/AbstractState.pyx:171, in CoolProp.CoolProp.AbstractState.all_critical_points()
#
# ValueError: p is not a valid number

# %%
print('Methane HEOS, phi 1:')
gas2.set_equivalence_ratio(1, fuel2, oxidizer)
AS = CP.AbstractState("HEOS", "Nitrogen&Methane&Oxygen")
AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
pts = AS.all_critical_points()
for pt in pts:
    print (pt.T)
    print (pt.p / 101325)
# Out:
# Methane HEOS, phi 1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 5
#       3 AS = CP.AbstractState("HEOS", "Nitrogen&Methane&Oxygen")
#       4 AS.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')],gas2.X[gas2.species_index('O2')]])
# ----> 5 pts = AS.all_critical_points()
#       6 for pt in pts:
#       7     print (pt.T)
#
# File CoolProp/AbstractState.pyx:168, in CoolProp.CoolProp.AbstractState.all_critical_points()
#
# File CoolProp/AbstractState.pyx:171, in CoolProp.CoolProp.AbstractState.all_critical_points()
#
# ValueError: No density solutions for T=28.5132,p=1.35739e+08,z=[ 0.0806340879968, 0.300057241091, 0.619308670912 ]

# %% [markdown]
# The all_critical_points routine gives all Mathematically valid solutions, which include true critical points, spinodal points, and other valid but physically infeasible values (see Methane SRK). The CoolProp doc also notes that the numerical methods required are far more complicated than those for pure fluids, causing it to fail, especially with nonstandard (non-refrigerant) mixtures with more than 2 partners(see Methane HEOS at phi >= 0.6). \
# Overall, the choice of backend affects the results, with SRK and PR being similar to each other, and HEOS differing greatly. \
# This is due them using different mixing rules and mixture parameters:
#
# SRK/PR uses van der Waals mixing, with a single kij parameter per binary pair. (see https://www.coolprop.org/dev/coolprop/Cubics.html#mixtures). It's considered less accurate, but very reliable at giving results.
#
# HEOS mixing is based on the works of Kunz et al (https://link.springer.com/article/10.1023/A:1022627001338) and Lemmon (https://pubs.acs.org/doi/10.1021/je300655b), the GERG-2008-like modified Benedict–Webb–Rubin (MBWR) model, with its own set of baked in interaction parameters. (see https://www.coolprop.org/dev/coolprop/Cubics.html#mixtures). It's considered very accurate due to the amount of parameters involved, but sometimes unreliable, especially for non-standard conditions (3+Species, No refrigerants).
#
#
# Due to the issues present with the all_critical_points routine, we implement some sanity checks:
# - We do not use the HEOS backend for Methane, as it seems to fail often.
# - We only save the critical points considered stable by CoolProp (checked with pt.stable)

# %% [markdown]
# We will first finalize the Methane Comparison.

# %%
#SRK
T_crit_list_SRK = []
p_crit_list_SRK = []

AS2 = CP.AbstractState("SRK", "N2&CH4&O2")
for i in phi:
    gas2.set_equivalence_ratio(i, fuel2, oxidizer) #Methane Fuel
    AS2.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')], gas2.X[gas2.species_index('O2')]])
    pts2 = AS2.all_critical_points()
    for pt2 in pts2:
        if pt2.stable: #Saves only "stable" results
            T_crit_list_SRK.append (pt2.T)
            p_crit_list_SRK.append (pt2.p / 101325)

# %%
#print (T_crit_list_SRK)
#print (p_crit_list_SRK)

# %%
#PR
T_crit_list_PR = []
p_crit_list_PR = []

AS3 = CP.AbstractState("PR", "N2&CH4&O2")
for i in phi:
    gas2.set_equivalence_ratio(i, fuel2, oxidizer)
    AS3.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')], gas2.X[gas2.species_index('O2')]])
    pts3 = AS3.all_critical_points()
    for pt3 in pts3:
        if pt3.stable: #Stable results only
            T_crit_list_PR.append (pt3.T)
            p_crit_list_PR.append (pt3.p / 101325)

# %%
#print (T_crit_list_PR)
#print (p_crit_list_PR)

# %% [markdown]
# For the HEOS Cases, we will use try-except blocks to try to find some phis, where we get results:

# %%
#Setting up a much finer phi, to check more values
phi2 = np.linspace(0.6,2, 141)
print (phi2)
# Out:
# [0.6  0.61 0.62 0.63 0.64 0.65 0.66 0.67 0.68 0.69 0.7  0.71 0.72 0.73
#  0.74 0.75 0.76 0.77 0.78 0.79 0.8  0.81 0.82 0.83 0.84 0.85 0.86 0.87
#  0.88 0.89 0.9  0.91 0.92 0.93 0.94 0.95 0.96 0.97 0.98 0.99 1.   1.01
#  1.02 1.03 1.04 1.05 1.06 1.07 1.08 1.09 1.1  1.11 1.12 1.13 1.14 1.15
#  1.16 1.17 1.18 1.19 1.2  1.21 1.22 1.23 1.24 1.25 1.26 1.27 1.28 1.29
#  1.3  1.31 1.32 1.33 1.34 1.35 1.36 1.37 1.38 1.39 1.4  1.41 1.42 1.43
#  1.44 1.45 1.46 1.47 1.48 1.49 1.5  1.51 1.52 1.53 1.54 1.55 1.56 1.57
#  1.58 1.59 1.6  1.61 1.62 1.63 1.64 1.65 1.66 1.67 1.68 1.69 1.7  1.71
#  1.72 1.73 1.74 1.75 1.76 1.77 1.78 1.79 1.8  1.81 1.82 1.83 1.84 1.85
#  1.86 1.87 1.88 1.89 1.9  1.91 1.92 1.93 1.94 1.95 1.96 1.97 1.98 1.99
#  2.  ]

# %%
#Setting up arrays for final HEOS values, as well as a reduced phi array (to put the working phis into)
T_crit_list_HEOS = []
p_crit_list_HEOS = []
phi2_red = []

AS4 = CP.AbstractState("HEOS", "N2&CH4&O2")
for i in phi2:
    gas2.set_equivalence_ratio(i, fuel2, oxidizer)
    AS4.set_mole_fractions([gas2.X[gas2.species_index('N2')],gas2.X[gas2.species_index('CH4')], gas2.X[gas2.species_index('O2')]])
#Set up a try except loop, to see if any solutions can be obtained
    try:
        pts4 = AS4.all_critical_points()
        for pt4 in pts4:
            if pt4.stable: #Only "stable" results
                T_crit_list_HEOS.append (pt4.T)
                p_crit_list_HEOS.append (pt4.p / 101325)
                phi2_red.append (i) #Saves the phis for which solutions were found
    except Exception as e:
        print("Error processing point at phi", i, e)
        continue  # Continue with next point
# Out:
# Error processing point at phi 0.6 Inputs in Brent [23619.336252,59145.365419] do not bracket the root.  Function values are [-1.000030,-0.970230]
# Error processing point at phi 0.64 p is not a valid number
# Error processing point at phi 0.65 p is not a valid number
# Error processing point at phi 0.6599999999999999 p is not a valid number
# Error processing point at phi 0.6699999999999999 p is not a valid number
# Error processing point at phi 0.7 p is not a valid number
# Error processing point at phi 0.72 p is not a valid number
# Error processing point at phi 0.84 No density solutions for T=27.3032,p=1.69666e+08,z=[ 0.0446483419665, 0.271347436043, 0.684004221991 ]
# Error processing point at phi 0.85 No density solutions for T=27.3823,p=1.67285e+08,z=[ 0.0466196492677, 0.273056471617, 0.680323879116 ]
# Error processing point at phi 0.87 No density solutions for T=27.5388,p=1.62643e+08,z=[ 0.050684579329, 0.276478293471, 0.6728371272 ]
# Error processing point at phi 0.88 No density solutions for T=27.6164,p=1.60379e+08,z=[ 0.052776630968, 0.278196256006, 0.669027113026 ]
# Error processing point at phi 0.8899999999999999 p is not a valid number
# Error processing point at phi 0.8999999999999999 No density solutions for T=27.7701,p=1.55961e+08,z=[ 0.0570757391267, 0.28165872454, 0.661265536334 ]
# Error processing point at phi 0.9099999999999999 No density solutions for T=27.8463,p=1.53804e+08,z=[ 0.0592810453713, 0.28340796703, 0.657310987599 ]
# Error processing point at phi 0.9199999999999999 No density solutions for T=27.922,p=1.51679e+08,z=[ 0.0615223148091, 0.285172219613, 0.653305465578 ]
# Error processing point at phi 0.9299999999999999 No density solutions for T=27.9973,p=1.49586e+08,z=[ 0.0637986207202, 0.28695360934, 0.649247769939 ]
# Error processing point at phi 0.94 No density solutions for T=28.0722,p=1.47524e+08,z=[ 0.0661090226128, 0.288754153594, 0.645136823793 ]
# Error processing point at phi 0.97 No density solutions for T=28.2945,p=1.41511e+08,z=[ 0.0732352783972, 0.294289107108, 0.632475614495 ]
# Error processing point at phi 0.98 No density solutions for T=28.3678,p=1.39562e+08,z=[ 0.0756725277156, 0.29618402803, 0.628143444254 ]
# Error processing point at phi 1.0 No density solutions for T=28.5132,p=1.35739e+08,z=[ 0.0806340879968, 0.300057241091, 0.619308670912 ]
# Error processing point at phi 1.01 No density solutions for T=28.5854,p=1.33864e+08,z=[ 0.0831565454597, 0.302037850534, 0.614805604007 ]
# Error processing point at phi 1.02 No density solutions for T=28.6572,p=1.32013e+08,z=[ 0.0857055835356, 0.304049086136, 0.610245330328 ]
# Error processing point at phi 1.03 No density solutions for T=28.7287,p=1.30185e+08,z=[ 0.0882803288997, 0.306091718076, 0.605627953024 ]
# Error processing point at phi 1.05 No density solutions for T=28.8707,p=1.26593e+08,z=[ 0.0910122239432, 0.298269437652, 0.610718338404 ]
# Error processing point at phi 1.06 No density solutions for T=28.9412,p=1.24828e+08,z=[ 0.0937877387012, 0.299872676257, 0.606339585042 ]
# Error processing point at phi 1.07 No density solutions for T=29.0114,p=1.23083e+08,z=[ 0.0965916108092, 0.301501443463, 0.601906945728 ]
# Error processing point at phi 1.18 Inputs in Brent [30006.973974,51609.540718] do not bracket the root.  Function values are [-2.933323,-183.906859]
# Error processing point at phi 1.19 Inputs in Brent [29998.840054,51609.758128] do not bracket the root.  Function values are [-2.952087,-185.544276]
# Error processing point at phi 1.2 Inputs in Brent [29990.749604,51609.975249] do not bracket the root.  Function values are [-2.971319,-187.218594]
# Error processing point at phi 1.21 Inputs in Brent [29982.701697,51610.192104] do not bracket the root.  Function values are [-2.991036,-188.931305]
# Error processing point at phi 1.22 Inputs in Brent [29974.695418,51610.408716] do not bracket the root.  Function values are [-3.011256,-190.683970]
# Error processing point at phi 1.23 Inputs in Brent [29966.729869,51610.625110] do not bracket the root.  Function values are [-3.032000,-192.478224]
# Error processing point at phi 1.24 Inputs in Brent [29958.804165,51610.841309] do not bracket the root.  Function values are [-3.053286,-194.315784]
# Error processing point at phi 1.26 Inputs in Brent [29943.068812,51611.273222] do not bracket the root.  Function values are [-3.097571,-198.128113]
# Error processing point at phi 1.28 Inputs in Brent [29927.482523,51611.704652] do not bracket the root.  Function values are [-3.144296,-202.136491]
# Error processing point at phi 1.29 Inputs in Brent [29919.743189,51611.920251] do not bracket the root.  Function values are [-3.168635,-204.219503]
# Error processing point at phi 1.3 Inputs in Brent [29912.038635,51612.135807] do not bracket the root.  Function values are [-3.193662,-206.358122]
# Error processing point at phi 1.31 Inputs in Brent [29904.368050,51612.351347] do not bracket the root.  Function values are [-3.219406,-208.554800]
# Error processing point at phi 1.3399999999999999 Inputs in Brent [29881.552139,51612.998142] do not bracket the root.  Function values are [-3.301253,-215.519833]
# Error processing point at phi 1.3599999999999999 p is not a valid number
# Error processing point at phi 1.37 Brent's method f(b) is NAN for b = 1, other input was a = 0
# Error processing point at phi 1.38 p is not a valid number
# Error processing point at phi 1.3900000000000001 p is not a valid number
# Error processing point at phi 1.4 p is not a valid number
# Error processing point at phi 1.4100000000000001 p is not a valid number
# Error processing point at phi 1.42 p is not a valid number
# Error processing point at phi 1.4300000000000002 p is not a valid number
# Error processing point at phi 1.44 p is not a valid number
# Error processing point at phi 1.45 p is not a valid number
# Error processing point at phi 1.46 Inputs in Brent [29792.854523,51615.602414] do not bracket the root.  Function values are [-3.717721,-250.669737]
# Error processing point at phi 1.47 p is not a valid number
# Error processing point at phi 1.48 p is not a valid number
# Error processing point at phi 1.49 p is not a valid number
# Error processing point at phi 1.5 p is not a valid number
# Error processing point at phi 1.51 p is not a valid number
# Error processing point at phi 1.52 p is not a valid number
# Error processing point at phi 1.53 p is not a valid number
# Error processing point at phi 1.54 p is not a valid number
# Error processing point at phi 1.5699999999999998 p is not a valid number
# Error processing point at phi 1.58 Inputs in Brent [29707.272106,51618.280868] do not bracket the root.  Function values are [-4.365290,-304.876808]
# Error processing point at phi 1.5899999999999999 Inputs in Brent [29700.238194,51618.509845] do not bracket the root.  Function values are [-4.435879,-310.769923]
# Error processing point at phi 1.6 Inputs in Brent [29693.215396,51618.739971] do not bracket the root.  Function values are [-4.509903,-316.947623]
# Error processing point at phi 1.6099999999999999 p is not a valid number
# Error processing point at phi 1.62 Inputs in Brent [29679.199482,51619.203936] do not bracket the root.  Function values are [-4.669320,-330.245366]
# Error processing point at phi 1.63 p is not a valid number
# Error processing point at phi 1.65 Inputs in Brent [29658.235449,51619.910237] do not bracket the root.  Function values are [-4.941664,-352.946111]
# Error processing point at phi 1.6600000000000001 p is not a valid number
# Error processing point at phi 1.6800000000000002 Inputs in Brent [29637.318655,51620.630881] do not bracket the root.  Function values are [-5.263688,-379.767505]
# Error processing point at phi 1.71 Inputs in Brent [29616.418716,51621.368362] do not bracket the root.  Function values are [-5.650622,-411.974504]
# Error processing point at phi 1.7200000000000002 Inputs in Brent [29609.450021,51621.618426] do not bracket the root.  Function values are [-5.797597,-424.203680]
# Error processing point at phi 1.77 Inputs in Brent [29574.526908,51622.906289] do not bracket the root.  Function values are [-6.719930,-500.909263]
# Error processing point at phi 1.79 Inputs in Brent [29560.489569,51623.441832] do not bracket the root.  Function values are [-7.209592,-541.613395]
# Error processing point at phi 1.8399999999999999 Inputs in Brent [29525.083068,51624.845518] do not bracket the root.  Function values are [-8.962764,-687.293490]
# Error processing point at phi 1.85 Inputs in Brent [29517.927481,51625.139428] do not bracket the root.  Function values are [-9.452911,-728.012475]
# Error processing point at phi 1.8599999999999999 Inputs in Brent [29510.739912,51625.438466] do not bracket the root.  Function values are [-10.013133,-774.549481]
# Error processing point at phi 1.87 Inputs in Brent [29503.516669,51625.743013] do not bracket the root.  Function values are [-10.659885,-828.270825]
# Error processing point at phi 1.9100000000000001 Inputs in Brent [29474.178154,51627.025600] do not bracket the root.  Function values are [-14.706211,-1164.319685]
# Error processing point at phi 1.92 Inputs in Brent [29466.705097,51627.365212] do not bracket the root.  Function values are [-16.366374,-1302.182131]
# Error processing point at phi 1.9300000000000002 Inputs in Brent [29459.163297,51627.713841] do not bracket the root.  Function values are [-18.518437,-1480.886065]
# Error processing point at phi 1.9500000000000002 Inputs in Brent [29443.838568,51628.441920] do not bracket the root.  Function values are [-25.559291,-2065.518683]

# %%
#print (T_crit_list_HEOS)
#print (phi2_red)

# %% [markdown]
# To get Laws data - which was only present graphically - we used WebPlotDigitizer (https://apps.automeris.io/wpd4/) \
# The Obtained data values are saved in a CSV and need to be importet before being used:

# %%
CH4_critP = pd.read_csv('Extracted Plots/Law_Fig2_CH4.csv')
CH4_critP.head() #Looks good
# Out:
#     phi          p           T
# 0  0.60  39.041106  135.336486
# 1  0.65  39.219932  135.712842
# 2  0.70  39.438490  136.066517
# 3  0.75  39.634464  136.435296
# 4  0.80  39.826543  136.787932

# %%
# %config InlineBackend.figure_formats = ['svg'] #Looks better!

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_SRK, ' ', color='g', marker='^', markersize=5, markerfacecolor='g', markevery=2, label='$SRK Critical Temperature$')
ax1.plot(phi,T_crit_list_PR, ' ', color='g', marker='o', markersize=4, markerfacecolor='g', markevery=2, label='$PR Critical Temperature$')
ax1.plot(phi2_red,T_crit_list_HEOS, ' ', color='g', marker='s', markersize=3, markerfacecolor='g', markevery=3, label='$HEOS Critical Temperature$')
ax1.plot(phi,T_c_mix_CH4, 'g--', label='$Pseudocritical Temperature$')
ax1.plot(CH4_critP['phi'], CH4_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_SRK, ' ', color='b', marker='^', markersize=5, markerfacecolor='b', markevery=2, label='$SRK Critical Pressure$')
ax2.plot(phi,p_crit_list_PR, ' ', color='b', marker='o', markersize=4, markerfacecolor='b', markevery=2, label='$SRK Critical Pressure$')
ax2.plot(phi2_red,p_crit_list_HEOS, ' ', color='b', marker='s', markersize=3, markerfacecolor='b', markevery=2, label='$HEOS Critical Pressure$')
ax2.plot(phi,P_c_mix_CH4, 'b--', label='$Pseudocritical Pressure$')
ax2.plot(CH4_critP['phi'], CH4_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 60)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
ax1.minorticks_on()
ax2.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='^', label='CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='o', label='CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='s', label='CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
    Line2D([0], [0], color='black', lw=2, linestyle='--', label='Kays Law Prediction')
]
ax1.legend(handles=custom_legend_lines, loc='lower right')
plt.savefig("Graphs/pTCrit of CH4.svg")
plt.show()

# %% [markdown]
# SRK and PR both agree closely with each other, and overpredict slightly at low phis compared Law Reference. \
# HEOS - if it delivers values at all - has outliers (due to multiple "valid" critical points found at those phis), and is visibly does not coincide with reference at most phis. \
# Kays Law comes reasonably close for predicting Tcrit at all phis, but is inaccurate for pCrit especially at higher phis.

# %% [markdown]
# Now lets try Hydrogen:

# %%
#SRK
#Arrays get indexed with _H2
T_crit_list_SRK_H2 = []
p_crit_list_SRK_H2 = []

AS5 = CP.AbstractState("SRK", "N2&H2&O2")
for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer) #H2 fuel
    AS5.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts5 = AS5.all_critical_points()
    for pt5 in pts5:
        if pt5.stable:
            T_crit_list_SRK_H2.append (pt5.T)
            p_crit_list_SRK_H2.append (pt5.p / 101325)

# %%
#PR
T_crit_list_PR_H2 = []
p_crit_list_PR_H2 = []


AS5 = CP.AbstractState("PR", "N2&H2&O2")
for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS5.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts5 = AS5.all_critical_points()
    for pt5 in pts5:
        if pt5.stable:
            T_crit_list_PR_H2.append (pt5.T)
            p_crit_list_PR_H2.append (pt5.p / 101325)

# %%
#HEOS
T_crit_list_HEOS_H2 = []
p_crit_list_HEOS_H2 = []
phi2_red_H2 = []

AS6 = CP.AbstractState("HEOS", "N2&H2&O2")
for i in phi2:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS6.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    try:
        pts6 = AS6.all_critical_points()
        for pt6 in pts6:
            if pt6.stable: #Only "stable" results
                T_crit_list_HEOS_H2.append (pt6.T)
                p_crit_list_HEOS_H2.append (pt6.p / 101325)
                phi2_red_H2.append (i)
    except Exception as e:
        print("Error processing point at phi", i, e)
        continue  # Continue with next point

# %% [markdown]
# The for loop finishes with no errors, however taking a closer look at the resulting phis reveals something strange:

# %%
print(phi2_red_H2)
# Out:
# [np.float64(0.6), np.float64(0.61), np.float64(0.62), np.float64(0.63), np.float64(0.64), np.float64(0.65), np.float64(0.6599999999999999), np.float64(0.6699999999999999), np.float64(0.6799999999999999), np.float64(0.69), np.float64(0.7), np.float64(0.71), np.float64(0.72), np.float64(0.73), np.float64(0.74), np.float64(0.75), np.float64(0.76), np.float64(0.77), np.float64(0.78), np.float64(0.79), np.float64(0.8), np.float64(0.8099999999999999), np.float64(0.82), np.float64(0.83), np.float64(0.84), np.float64(0.85), np.float64(0.86), np.float64(0.87), np.float64(0.88), np.float64(0.8899999999999999), np.float64(0.8999999999999999), np.float64(0.9099999999999999), np.float64(0.9199999999999999), np.float64(0.9299999999999999), np.float64(0.94), np.float64(0.95), np.float64(0.96), np.float64(0.97), np.float64(0.98), np.float64(0.99), np.float64(1.0), np.float64(1.01), np.float64(1.02), np.float64(1.03), np.float64(1.04), np.float64(1.05), np.float64(1.06), np.float64(1.07), np.float64(1.08), np.float64(1.0899999999999999), np.float64(1.1), np.float64(1.1099999999999999), np.float64(1.12), np.float64(1.13), np.float64(1.1400000000000001), np.float64(1.15), np.float64(1.1600000000000001), np.float64(1.17), np.float64(1.18), np.float64(1.19), np.float64(1.2), np.float64(1.21), np.float64(1.21), np.float64(1.22), np.float64(1.22), np.float64(1.23), np.float64(1.23), np.float64(1.24), np.float64(1.24), np.float64(1.25), np.float64(1.25), np.float64(1.26), np.float64(1.26), np.float64(1.27), np.float64(1.27), np.float64(1.28), np.float64(1.28), np.float64(1.29), np.float64(1.29), np.float64(1.3), np.float64(1.3), np.float64(1.31), np.float64(1.31), np.float64(1.3199999999999998), np.float64(1.3199999999999998), np.float64(1.33), np.float64(1.33), np.float64(1.3399999999999999), np.float64(1.3399999999999999), np.float64(1.35), np.float64(1.35), np.float64(1.3599999999999999), np.float64(1.3599999999999999), np.float64(1.37), np.float64(1.37), np.float64(1.38), np.float64(1.38), np.float64(1.3900000000000001), np.float64(1.3900000000000001), np.float64(1.4), np.float64(1.4), np.float64(1.4100000000000001), np.float64(1.4100000000000001), np.float64(1.42), np.float64(1.42), np.float64(1.4300000000000002), np.float64(1.4300000000000002), np.float64(1.44), np.float64(1.44), np.float64(1.45), np.float64(1.45), np.float64(1.46), np.float64(1.46), np.float64(1.47), np.float64(1.47), np.float64(1.48), np.float64(1.48), np.float64(1.49), np.float64(1.49), np.float64(1.5), np.float64(1.5), np.float64(1.51), np.float64(1.51), np.float64(1.52), np.float64(1.52), np.float64(1.53), np.float64(1.53), np.float64(1.54), np.float64(1.54)]

# %% [markdown]
# The all_critical_points routine for HEOS Hydrogen mixes seems to silently fail at phis above 1.54!

# %%
H2_critP = pd.read_csv('Extracted Plots/Law_Fig2_H2.csv')
H2_critP.head() #Looks good
# Out:
#     phi          p           T
# 0  0.60  25.837759  108.611254
# 1  0.65  25.190512  107.140606
# 2  0.70  24.526053  105.706336
# 3  0.75  23.915836  104.376376
# 4  0.80  23.305619  103.020338

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_SRK_H2, ' ', color='g', marker='^', markersize=5, markerfacecolor='g', label='$SRK Critical Temperature$')
ax1.plot(phi,T_crit_list_PR_H2, ' ', color='g', marker='o', markersize=4, markerfacecolor='g', label='$PR Critical Temperature$')
ax1.plot(phi2_red_H2,T_crit_list_HEOS_H2, ' ', color='g', marker='s', markersize=3, markerfacecolor='g', label='$HEOS Critical Temperature$')
ax1.plot(phi,T_c_mix_H2, 'g--', label='$Pseudocritical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_SRK_H2, ' ', color='b', marker='^', markersize=5, markerfacecolor='b', label='$SRK Critical Pressure$')
ax2.plot(phi,p_crit_list_PR_H2, ' ', color='b', marker='o', markersize=4, markerfacecolor='b', label='$SRK Critical Pressure$')
ax2.plot(phi2_red_H2,p_crit_list_HEOS_H2, ' ', color='b', marker='s', markersize=3, markerfacecolor='b', label='$HEOS Critical Pressure$')
ax2.plot(phi,P_c_mix_H2, 'b--', label='$Pseudocritical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='^', label='CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='o', label='CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='s', label='CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
    Line2D([0], [0], color='black', lw=2, linestyle='--', label='Kays Law Prediction')
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2.svg")
plt.show()

# %% [markdown]
# This is a mess! \
# All CoolProp backends are massively off from our reference! \
# - CoolProps SRK and PR backends are grouped together, but disagree on pCrit at higher phis. Tcrit has a downward trend just as reference, but Pcrit increases instead. Both are far off from reference.
# - CoolProps HEOS backend often predicts multiple Tcrit for each phi, and a rapidly balooning Pcrit. Additionally, there are no values above a phi of 1.54! I don't know what to make of this.
#
# Kays Law comes closest to our reference in terms of value and general trend, but diverges further at higher phis.

# %% [markdown]
# # Tuning binary interaction parameters to change results
#
# CoolProp lets us customize the binary interaction parameters both for the Cubic and HEOS backends. \
# We will be using the Low Level Interface for this (see https://www.coolprop.org/fluid_properties/Mixtures.html#using-your-own-interaction-parameters) \
# Lets try changing the parameters in the HEOS backend first:

# %%
#Taking a look at starting interaction parameters
AS_mod = CP.AbstractState("HEOS", "N2&H2&O2")
#0 is N2, 1 is H2, 2 is O2
print('N2-H2 Interaction Parameters:')
print(AS_mod.get_binary_interaction_double(0, 1, 'betaT'),AS_mod.get_binary_interaction_double(0, 1, 'gammaT'),\
      AS_mod.get_binary_interaction_double(0, 1, 'betaV'),AS_mod.get_binary_interaction_double(0, 1, 'gammaV'))
print(' ')
print('H2-O2 Interaction Parameters:')
print(AS_mod.get_binary_interaction_double(1, 2, 'betaT'),AS_mod.get_binary_interaction_double(1, 2, 'gammaT'),\
      AS_mod.get_binary_interaction_double(1, 2, 'betaV'),AS_mod.get_binary_interaction_double(1, 2, 'gammaV'))
print(' ')
print('N2-O2 Interaction Parameters:')
print(AS_mod.get_binary_interaction_double(0, 2, 'betaT'),AS_mod.get_binary_interaction_double(0, 2, 'gammaT'),\
      AS_mod.get_binary_interaction_double(0, 2, 'betaV'),AS_mod.get_binary_interaction_double(0, 2, 'gammaV'))
# Out:
# N2-H2 Interaction Parameters:
# 0.9461343370000002 1.175696583 0.9725320649999999 0.970115357
#
# H2-O2 Interaction Parameters:
# 1.0 1.0 1.0 1.0
#
# N2-O2 Interaction Parameters:
# 0.997190589 0.995157044 0.99952177 0.997082328

# %%
#Setting Fractions for a phi of 0.6
gas1.set_equivalence_ratio(0.6, fuel, oxidizer)

# %% [markdown]
# It seems the Interaction parameters for H2-O2 have been approximated using the Lorentz-Berthelot Method (all are set to 1). \

# %%
#Initializing AS_mod
AS_mod = CP.AbstractState("HEOS", "N2&H2&O2")
AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])

#Resulting Critical Properties
print ('Unmodified HEOS:')
pts_mod = AS_mod.all_critical_points()
for pt_mod in pts_mod:
    if pt_mod.stable: #Only "stable" results
        print(pt_mod.T)
        print (pt_mod.p / 101325)
# Out:
# Unmodified HEOS:
# 129.92777202059656
# 75.58103434747937

# %%
#Reference Values from the Law_Fig2_H2.csv
Reference_P = H2_critP.iloc[1, 1] #location of pCrit at 0.6 phi
Reference_T = H2_critP.iloc[1, 2] #location of Tcrit at 0.6 phi
print ('Law Reference:')
print (Reference_T)
print (Reference_P)
# Out:
# Law Reference:
# 107.140606383236
# 25.1905116056238

# %% [markdown]
# Lets try changing the H2-O2 parameters to those of N2:

# %%
#These changes are only per-object and get overwritten when reinitializing the AbstractState!
AS_mod.set_binary_interaction_double(1, 2, 'betaT', 0.946134337)
AS_mod.set_binary_interaction_double(1, 2, 'gammaT', 1.175696583)
AS_mod.set_binary_interaction_double(1, 2, 'betaV', 0.972532065)
AS_mod.set_binary_interaction_double(1, 2, 'gammaV', 0.970115357)

#Check that the parameters have been applied
print(AS_mod.get_binary_interaction_double(1, 2, 'betaT'),AS_mod.get_binary_interaction_double(1, 2, 'gammaT'),\
      AS_mod.get_binary_interaction_double(1, 2, 'betaV'),AS_mod.get_binary_interaction_double(1, 2, 'gammaV'))
# Out:
# 0.946134337 1.175696583 0.972532065 0.970115357

# %%
#Lets take a look at the changes
print ('Modified HEOS:')
AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
pts_mod = AS_mod.all_critical_points()
for pt_mod in pts_mod:
    if pt_mod.stable: #Only "stable" results
        print(pt_mod.T)
        print (pt_mod.p / 101325)
# Out:
# Modified HEOS:
# 129.0066174158181
# 71.3763753376282

# %% [markdown]
# Lets calculate other phis as well:

# %%
#HEOS
T_mod_list_HEOS = []
p_mod_list_HEOS = []
phi2_mod_red = []

for i in phi2:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    try:
        pts_mod = AS_mod.all_critical_points()
        for pt_mod in pts_mod:
            if pt_mod.stable: #Only "stable" results
                T_mod_list_HEOS.append (pt_mod.T)
                p_mod_list_HEOS.append (pt_mod.p / 101325)
                phi2_mod_red.append (i)
    except Exception as e:
        print("Error processing point at phi", i, e)
        continue  # Continue with next point

# %%
#Double Checking that the changed parameters are still active
print(AS_mod.get_binary_interaction_double(1, 2, 'betaT'),AS_mod.get_binary_interaction_double(1, 2, 'gammaT'),\
      AS_mod.get_binary_interaction_double(1, 2, 'betaV'),AS_mod.get_binary_interaction_double(1, 2, 'gammaV'))
# Out:
# 0.946134337 1.175696583 0.972532065 0.970115357

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi2_red_H2,T_crit_list_HEOS_H2, ' ', color='g', marker='s', markersize=3, markerfacecolor='g', label='$HEOS Critical Temperature$')
ax1.plot(phi2_mod_red,T_mod_list_HEOS, ' ', color='g', marker='+', markersize=4, markerfacecolor='g', label='$Parameter Modified HEOS Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi2_red_H2,p_crit_list_HEOS_H2, ' ', color='b', marker='s', markersize=3, markerfacecolor='b', label='$HEOS Critical Pressure$')
ax2.plot(phi2_mod_red,p_mod_list_HEOS, ' ', color='b', marker='+', markersize=4, markerfacecolor='b', label='$Parameter Modified HEOS Critical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='s', label='CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='+', label='Modified CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference')
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 Modified InteractionParameters.svg")
plt.show()

# %% [markdown]
# Lets try tuning the parameters to get a lower Pressure at higher phis: \
# We will perform a grid search with a rough step size (to save on calculation time), checking at which values a minimum is reached:

# %%
#Setting up arrays, 4x4x5x4 = 320 Combinations
#Change bounds and increase nr of steps if wanted
bT_list = np.linspace(0.94,1.08, 4)
gT_list = np.linspace(1,2, 5)
bV_list = np.linspace(0.9,1.1, 4)
gV_list = np.linspace(0.97,1.17, 4)


#Setting phi to 1.4, middle of the road for reference case
gas1.set_equivalence_ratio(1.4, fuel, oxidizer)
AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])


import itertools #Importing itertools to do a grid search

# %% [markdown]
# The search Loop follows. Careful! It takes a while to calculate

# %%
#Initialising Final value arrays
P_minlist = []
I_minlist = []

#Search Loop
for bT, gT, bV, gV in itertools.product(bT_list, gT_list, bV_list, gV_list):
    AS_mod.set_binary_interaction_double(1, 2, 'betaT', bT)
    AS_mod.set_binary_interaction_double(1, 2, 'gammaT', gT)
    AS_mod.set_binary_interaction_double(1, 2, 'betaV', bV)
    AS_mod.set_binary_interaction_double(1, 2, 'gammaV', gV)
    pts_mod = AS_mod.all_critical_points()
    try:
        pts_mod = AS_mod.all_critical_points()
        for pt_mod in pts_mod:
            if pt_mod.stable:
                P_minlist.append(pt_mod.p)
                I_minlist.append((bT, gT, bV, gV))   # Stores the parameter-set
    except ValueError: #Skips Values that error out
        continue

# %%
#Find the minimum value from the resulting array
min_index = np.argmin(P_minlist)

#Correspond it to the interaction array
bTmin, gTmin, bVmin, gVmin = I_minlist[min_index]

#Print results
print(f"Minimum Pressure: {P_minlist[min_index]/101325:.4f} atm")
print(f"Corresponding parameters:")
print(f"  betaT = {bTmin}")
print(f"  gammaT = {gTmin}")
print(f"  betaV = {bVmin}")
print(f"  gammaV = {gVmin}")
# Out:
# Minimum Pressure: 75.0428 atm
# Corresponding parameters:
#   betaT = 0.94
#   gammaT = 2.0
#   betaV = 0.9
#   gammaV = 1.17

# %% [markdown]
# Let's set the values, then calculate other phis:

# %%
#Setting the Values
AS_mod.set_binary_interaction_double(1, 2, 'betaT', bTmin)
AS_mod.set_binary_interaction_double(1, 2, 'gammaT', gTmin)
AS_mod.set_binary_interaction_double(1, 2, 'betaV', bVmin)
AS_mod.set_binary_interaction_double(1, 2, 'gammaV', gVmin)

# %%
#HEOS
T_tuned_list_HEOS = []
p_tuned_list_HEOS = []
phi2_tuned_red = []

for i in phi2:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    try:
        pts_mod = AS_mod.all_critical_points()
        for pt_mod in pts_mod:
            if pt_mod.stable: #Only "stable" results
                T_tuned_list_HEOS.append (pt_mod.T)
                p_tuned_list_HEOS.append (pt_mod.p / 101325)
                phi2_tuned_red.append (i)
    except Exception as e:
        print("Error processing point at phi", i, e)
        continue  # Continue with next point

# %%
#Double Checking that the changed parameters have been set correctly
print(AS_mod.get_binary_interaction_double(1, 2, 'betaT'),AS_mod.get_binary_interaction_double(1, 2, 'gammaT'),\
      AS_mod.get_binary_interaction_double(1, 2, 'betaV'),AS_mod.get_binary_interaction_double(1, 2, 'gammaV'))
# Out:
# 0.94 2.0 0.9 1.17

# %%
#Plotting the tuned results
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi2_red_H2,T_crit_list_HEOS_H2, ' ', color='g', marker='s', markersize=3, markerfacecolor='g', label='$HEOS Critical Temperature$')
ax1.plot(phi2_tuned_red,T_tuned_list_HEOS, ' ', color='g', marker='*', markersize=4, markerfacecolor='g', label='$Parameter Tuned HEOS Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi2_red_H2,p_crit_list_HEOS_H2, ' ', color='b', marker='s', markersize=3, markerfacecolor='b', label='$HEOS Critical Pressure$')
ax2.plot(phi2_tuned_red,p_tuned_list_HEOS, ' ', color='b', marker='*', markersize=4, markerfacecolor='g', label='$Parameter Tuned HEOS Critical Temperature$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='s', label='CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='*', label='Tuned CoolProp HEOS'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference')
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 Tuned InteractionParameters.svg")
plt.show()

# %% [markdown]
# Overall: Changing parameters for the HEOS backend influences the results majorly, but is still far from reference values!

# %%
#Querying rho from H Mix, weird behaviour when T too high with high H content
gas1.set_equivalence_ratio(1, fuel, oxidizer)
AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
AS_mod.update(CP.PT_INPUTS, 101325, 275)
print(AS_mod.rhomass())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 3
#       1 #Querying rho from H Mix, weird behaviour when T too high with high H content
#       2 AS_mod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
# ----> 3 AS_mod.update(CP.PT_INPUTS, 101325, 275)
#       4 print(AS_mod.rhomass())
#
# File CoolProp/AbstractState.pyx:106, in CoolProp.CoolProp.AbstractState.update()
#
# File CoolProp/AbstractState.pyx:108, in CoolProp.CoolProp.AbstractState.update()
#
# ValueError: One stationary point (not good) for T=275,p=101325,z=[ 0.363927589095, 0.516111924988, 0.119960485917 ]

# %% [markdown]
# Onto the Cubics: Both use the kij binary interaction parameter, which is defined internally for each binary pair, and can be modified using the "set_binary_interaction_double" function. \
# CoolProp does not come with any values for the kij parameter itself! Instead it relies on its REFPROP integration to grab them. (We dont have access to REFPROP)

# %%
AS_SRKmod = CP.AbstractState("SRK", "N2&H2&O2")

print(AS_SRKmod.get_binary_interaction_double(0,1,"kij"),AS_SRKmod.get_binary_interaction_double(1,2,"kij"),\
      AS_SRKmod.get_binary_interaction_double(0,2,"kij"))
#All Parameters are 0 (standard value)
# Out:
# 0.0 0.0 0.0

# %%
gas1.set_equivalence_ratio(0.6, fuel, oxidizer)
AS_SRKmod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])

#Resulting Critical Properties
print ('Unmodified SRK:')
pts_mod = AS_SRKmod.all_critical_points()
for pt_mod in pts_mod:
    if pt_mod.stable: #Only "stable" results
        print(pt_mod.T)
        print (pt_mod.p / 101325)
# Out:
# Unmodified SRK:
# 124.7152629381777
# 55.541456894386506

# %% [markdown]
# Lets try changing the parameter:

# %%
AS_SRKmod.set_binary_interaction_double(0, 1, "kij", -0.1)
AS_SRKmod.set_binary_interaction_double(1, 2, "kij", 0)
AS_SRKmod.set_binary_interaction_double(0, 2, "kij", 0.1)

print(AS_SRKmod.get_binary_interaction_double(0,1,"kij"),AS_SRKmod.get_binary_interaction_double(1,2,"kij"),\
      AS_SRKmod.get_binary_interaction_double(0,2,"kij"))
# Out:
# -0.1 0.0 0.1

# %%
print ('Modified SRK:')
pts_mod = AS_SRKmod.all_critical_points()
for pt_mod in pts_mod:
    if pt_mod.stable: #Only "stable" results
        print(pt_mod.T)
        print (pt_mod.p / 101325)
# Out:
# Modified SRK:
# 106.83272634145436
# 79.525435671048

# %% [markdown]
# Now to visualize the change:

# %%
#SRK

T_crit_list_SRKmod = []
p_crit_list_SRKmod = []

AS_SRKmod = CP.AbstractState("SRK", "N2&H2&O2")
AS_SRKmod.set_binary_interaction_double(0, 1, "kij", -0.1)
AS_SRKmod.set_binary_interaction_double(1, 2, "kij", 0)
AS_SRKmod.set_binary_interaction_double(0, 2, "kij", 0.1)

for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_SRKmod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts_mod = AS_SRKmod.all_critical_points()
    for pt_mod in pts_mod:
        if pt_mod.stable:
            T_crit_list_SRKmod.append(pt_mod.T)
            p_crit_list_SRKmod.append(pt_mod.p / 101325)

# %%
#PR

T_crit_list_PRmod = []
p_crit_list_PRmod = []

AS_PRmod = CP.AbstractState("PR", "N2&H2&O2")
AS_PRmod.set_binary_interaction_double(0, 1, "kij", -0.1)
AS_PRmod.set_binary_interaction_double(1, 2, "kij", 0)
AS_PRmod.set_binary_interaction_double(0, 2, "kij", 0.1)

for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_PRmod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts_mod = AS_PRmod.all_critical_points()
    for pt_mod in pts_mod:
        if pt_mod.stable:
            T_crit_list_PRmod.append(pt_mod.T)
            p_crit_list_PRmod.append(pt_mod.p / 101325)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_SRK_H2, ' ', color='g', marker='^', markersize=5, markerfacecolor='g', label='$SRK Critical Temperature$')
ax1.plot(phi,T_crit_list_SRKmod, ' ', color='g', marker='*', markersize=5, markerfacecolor='g', label='$Modified SRK Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_SRK_H2, ' ', color='b', marker='^', markersize=5, markerfacecolor='b', label='$SRK Critical Pressure$')
ax2.plot(phi,p_crit_list_SRKmod, ' ', color='b', marker='*', markersize=5, markerfacecolor='b', label='$Modified SRK Critical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='^', label='CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='*', label='Modified CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 SRK Modified.svg")
plt.show()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_PR_H2, ' ', color='g', marker='o', markersize=5, markerfacecolor='g', label='$PR Critical Temperature$')
ax1.plot(phi,T_crit_list_PRmod, ' ', color='g', marker='+', markersize=5, markerfacecolor='g', label='$Modified PR Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_PR_H2, ' ', color='b', marker='o', markersize=5, markerfacecolor='b', label='$PR Critical Pressure$')
ax2.plot(phi,p_crit_list_PRmod, ' ', color='b', marker='+', markersize=5, markerfacecolor='b', label='$Modified PR Critical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='o', label='CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='+', label='Modified CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 PR Modified.svg")
plt.show()

# %% [markdown]
# Now, the same as HEOS, we will try varying the kij parameters from -0.1 to 0.6 and perform a grid search. \
# However instead of finding the lowest pressure we will try to match closest with our reference:

# %%
#Setting three separate kijs, so that search space remains large, 8x8x8 = 512 Value  Combinations
#Change bounds and nr of steps if wanted
kij1_list = np.linspace(-0.1,0.6, 8)
kij2_list = np.linspace(-0.1,0.6, 8)
kij3_list = np.linspace(-0.1,0.6, 8)

reference = H2_critP.iloc[19, 1]  # pCrit at phi 1.5

#Setting phi to 1.5
gas1.set_equivalence_ratio(1.5, fuel, oxidizer)

AS_SRKmod = CP.AbstractState("SRK", "N2&H2&O2")
AS_SRKmod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])

AS_PRmod = CP.AbstractState("PR", "N2&H2&O2")
AS_PRmod.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])

# Importing itertools if not already done so
# import itertools

# %%
#SRK

#Initialising Final value arrays
P_minlist = []
I_minlist = []

#Search Loop
for kij1, kij2, kij3 in itertools.product(kij1_list, kij2_list, kij3_list):
    AS_SRKmod.set_binary_interaction_double(0, 1, "kij", kij1)
    AS_SRKmod.set_binary_interaction_double(1, 2, "kij", kij2)
    AS_SRKmod.set_binary_interaction_double(0, 2, "kij", kij3)
    try:
        pts_mod = AS_SRKmod.all_critical_points()
        for pt_mod in pts_mod:
            if pt_mod.stable:
                P_minlist.append(pt_mod.p/101325)
                I_minlist.append((kij1, kij2, kij3))  
    except ValueError: #Skip/Bypass errors
        continue


# Subtract the reference and calculate the minimum of the absolute value
# Basically how close we are to reference
adjusted = [abs(p - reference) for p in P_minlist]
min_index = np.argmin(adjusted)


#Correspond it to the interaction array
kij1, kij2, kij3 = I_minlist[min_index]

#Print results
print(f"Minimum Pressure: {P_minlist[min_index]:.4f} atm")
print(f"Corresponding parameters:")
print(f"  N2-H2 = {kij1}")
print(f"  H2-O2 = {kij2}")
print(f"  N2-O2 = {kij3}")
# Out:
# Minimum Pressure: 59.2545 atm
# Corresponding parameters:
#   N2-H2 = -0.1
#   H2-O2 = -0.1
#   N2-O2 = 0.3999999999999999

# %%
#Using calculated values in SRK

T_crit_list_SRKtune = []
p_crit_list_SRKtune = []

AS_SRKtune = CP.AbstractState("SRK", "N2&H2&O2")
AS_SRKtune.set_binary_interaction_double(0, 1, "kij", -0.1)
AS_SRKtune.set_binary_interaction_double(1, 2, "kij", 0)
AS_SRKtune.set_binary_interaction_double(0, 2, "kij", 0.1)

for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_SRKtune.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts_mod = AS_SRKtune.all_critical_points()
    for pt_mod in pts_mod:
        if pt_mod.stable:
            T_crit_list_SRKtune.append(pt_mod.T)
            p_crit_list_SRKtune.append(pt_mod.p / 101325)

# %%
#PR

#Reinitialising arrays
P_minlist = []
I_minlist = []

#Search Loop
for kij4, kij5, kij6 in itertools.product(kij1_list, kij2_list, kij3_list):
    AS_PRmod.set_binary_interaction_double(0, 1, "kij", kij4)
    AS_PRmod.set_binary_interaction_double(1, 2, "kij", kij5)
    AS_PRmod.set_binary_interaction_double(0, 2, "kij", kij6)
    try:
        pts_mod = AS_PRmod.all_critical_points()
        for pt_mod in pts_mod:
            if pt_mod.stable:
                P_minlist.append(pt_mod.p/101325)
                I_minlist.append((kij4, kij5, kij6))  
    except ValueError: #Skip/Bypass errors
        continue


adjusted = [abs(p - reference) for p in P_minlist]
min_index = np.argmin(adjusted)

kij4, kij5, kij6 = I_minlist[min_index]

#Results
print(f"Minimum Pressure: {P_minlist[min_index]:.4f} atm")
print(f"Corresponding parameters:")
print(f"  N2-H2 = {kij4}")
print(f"  H2-O2 = {kij5}")
print(f"  N2-O2 = {kij6}")
# Out:
# Minimum Pressure: 56.4391 atm
# Corresponding parameters:
#   N2-H2 = -0.1
#   H2-O2 = -0.1
#   N2-O2 = 0.3999999999999999

# %%
#Using the just calculated parameters

T_crit_list_PRtune = []
p_crit_list_PRtune = []

AS_PRtune = CP.AbstractState("PR", "N2&H2&O2")
AS_PRtune.set_binary_interaction_double(0, 1, "kij", kij1)
AS_PRtune.set_binary_interaction_double(1, 2, "kij", kij2)
AS_PRtune.set_binary_interaction_double(0, 2, "kij", kij3)

for i in phi:
    gas1.set_equivalence_ratio(i, fuel, oxidizer)
    AS_PRtune.set_mole_fractions([gas1.X[gas1.species_index('N2')],gas1.X[gas1.species_index('H2')], gas1.X[gas1.species_index('O2')]])
    pts_mod = AS_PRtune.all_critical_points()
    for pt_mod in pts_mod:
        if pt_mod.stable:
            T_crit_list_PRtune.append(pt_mod.T)
            p_crit_list_PRtune.append(pt_mod.p / 101325)

# %% [markdown]
# Now to plot the results:

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_SRK_H2, ' ', color='g', marker='^', markersize=5, markerfacecolor='g', label='$SRK Critical Temperature$')
ax1.plot(phi,T_crit_list_SRKtune, ' ', color='g', marker='*', markersize=5, markerfacecolor='g', label='$Tuned SRK Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_SRK_H2, ' ', color='b', marker='^', markersize=5, markerfacecolor='b', label='$SRK Critical Pressure$')
ax2.plot(phi,p_crit_list_SRKtune, ' ', color='b', marker='*', markersize=5, markerfacecolor='b', label='$Tuned SRK Critical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='^', label='CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='*', label='Tuned CoolProp SRK'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 SRK Tuned.svg")
plt.show()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(phi,T_crit_list_PR_H2, ' ', color='g', marker='^', markersize=5, markerfacecolor='g', label='$PR Critical Temperature$')
ax1.plot(phi,T_crit_list_PRtune, ' ', color='g', marker='*', markersize=5, markerfacecolor='g', label='$Tuned PR Critical Temperature$')
ax1.plot(H2_critP['phi'], H2_critP['T'], 'g-', label='$Reference Critical Pressure$')
ax2.plot(phi,p_crit_list_PR_H2, ' ', color='b', marker='^', markersize=5, markerfacecolor='b', label='$PR Critical Pressure$')
ax2.plot(phi,p_crit_list_PRtune, ' ', color='b', marker='*', markersize=5, markerfacecolor='b', label='$Tuned PR Critical Pressure$')
ax2.plot(H2_critP['phi'], H2_critP['p'], 'b-', label='$Reference Critical Pressure$')
ax1.set_xlabel('Equivalence Ratio')
ax1.set_ylabel('Crit. Temperature [K]', color='g')
ax2.set_ylabel('Crit. Pressure [atm]', color='b')
ax1.set_xlim(0.6, 2)
ax1.set_ylim(60, 160)
ax2.set_xlim(0.6, 2)
ax2.set_ylim(8, 180)
ax1.set_xticks([0.6, 1, 1.5, 2])
ax1.set_yticks([60, 80, 100, 120, 140, 160])
ax2.set_yticks([10, 20, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180])
ax1.minorticks_on()
custom_legend_lines = [
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='^', label='CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle=' ', marker='*', label='Tuned CoolProp PR'),
    Line2D([0], [0], color='black', lw=2, linestyle='-', label='Law Reference'),
]
ax1.legend(handles=custom_legend_lines, loc='upper left')
plt.savefig("Graphs/pTCrit of H2 PR Tuned.svg")
plt.show()

# %% [markdown]
# Despite some efforts, these results are very different compared to what Law et al get.
